# %%
import cv2

# %%
cv2.__version__
# Out:
# '3.3.0'

# %%
print(cv2.getBuildInformation())
# Out:
# General configuration for OpenCV 3.3.0 =====================================
#   Version control:               unknown
#
#   Extra modules:
#     Location (extra):            /opencv_contrib-3.3.0/modules
#     Version control (extra):     unknown
#
#   Platform:
#     Timestamp:                   2017-11-13T09:41:56Z
#     Host:                        Linux 4.9.49-moby x86_64
#     CMake:                       3.0.2
#     CMake generator:             Unix Makefiles
#     CMake build tool:            /usr/bin/make
#     Configuration:               RELEASE
#
#   CPU/HW features:
#     Baseline:                    SSE SSE2 SSE3 SSSE3 SSE4_1 POPCNT SSE4_2 AVX
#       requested:                 SSE3
#       required:                  AVX
#     Dispatched code generation:  FP16 AVX2
#       requested:                 SSE4_1 SSE4_2 AVX FP16 AVX2
#       FP16 (1 files):            + FP16
#       AVX2 (7 files):            + FP16 FMA3 AVX2
#
#   C/C++:
# ...
